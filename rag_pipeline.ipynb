# %% [markdown]
# This is a notebook implements the qdrant databases, as well as performing RAG experiments with the databases.
#
# In this notebook, we use 4-bit quantization to run Llama-7B Chat model. This code uses only 10 GB of VRAM. It can run on a free instance of Google Colab or on a local GPU (e.g., RTX 3060 12GB).
# [More details here.](https://open.substack.com/pub/kaitchup/p/run-llama-2-chat-models-on-your-computer?r=2kp66c&utm_campaign=post&utm_medium=web)
#
#
# We only need the following libraries:
#
#
# *   transformers
# *   accelerate (for device_map)
# *   bitsandbytes (for 4-bit quantization)

# %%
# %pip install qdrant-client sentence-transformers accelerate
# %pip install langchain-groq
# Out:
# Requirement already satisfied: qdrant-client in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (1.8.2)
# Requirement already satisfied: sentence-transformers in c:\users\dng09\appdata\roaming\python\python310\site-packages (2.2.2)
# Requirement already satisfied: accelerate in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (0.28.0)
# Requirement already satisfied: grpcio>=1.41.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from qdrant-client) (1.62.1)
# Requirement already satisfied: grpcio-tools>=1.41.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from qdrant-client) (1.62.1)
# Requirement already satisfied: httpx[http2]>=0.20.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from qdrant-client) (0.27.0)
# Requirement already satisfied: numpy>=1.21 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from qdrant-client) (1.24.4)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from qdrant-client) (2.8.2)
# Requirement already satisfied: pydantic>=1.10.8 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from qdrant-client) (2.6.4)
# Requirement already satisfied: urllib3<3,>=1.26.14 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from qdrant-client) (1.26.18)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\dng09\appdata\roaming\python\python310\site-packages (from sentence-transformers) (4.24.0)
# Requirement already satisfied: tqdm in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (2.0.1)
# Requirement already satisfied: torchvision in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (0.15.2)
# Requirement already satisfied: scikit-learn in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (1.8.1)
# Requirement already satisfied: nltk in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (3.7)
# Requirement already satisfied: sentencepiece in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (0.1.97)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (0.20.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from accelerate) (5.9.1)
# Requirement already satisfied: pyyaml in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from accelerate) (5.4.1)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from accelerate) (0.4.2)
# Requirement already satisfied: protobuf<5.0dev,>=4.21.6 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from grpcio-tools>=1.41.0->qdrant-client) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from grpcio-tools>=1.41.0->qdrant-client) (58.1.0)
# Requirement already satisfied: anyio in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client) (3.6.2)
# Requirement already satisfied: certifi in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client) (2022.9.24)
# Requirement already satisfied: httpcore==1.* in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client) (1.0.5)
# Requirement already satisfied: idna in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client) (3.4)
# Requirement already satisfied: sniffio in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client) (1.3.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client) (4.1.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx[http2]>=0.20.0->qdrant-client) (0.14.0)
# Requirement already satisfied: filelock in c:\users\dng09\appdata\roaming\python\python310\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.8.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.10.0)
# Requirement already satisfied: requests in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.28.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.10.0)
# Requirement already satisfied: pywin32>=226 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from portalocker<3.0.0,>=2.7.0->qdrant-client) (304)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=1.10.8->qdrant-client) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=1.10.8->qdrant-client) (2.16.3)
# Requirement already satisfied: sympy in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: colorama in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from tqdm->sentence-transformers) (0.4.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.9.13)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.13.2)
# Requirement already satisfied: click in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: joblib in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from torchvision->sentence-transformers) (9.3.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -orch (c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: langchain-groq in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (0.0.1)
# Requirement already satisfied: groq<1,>=0.4.1 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from langchain-groq) (0.4.2)
# Requirement already satisfied: langchain-core<0.2,>=0.1 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from langchain-groq) (0.1.35)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (3.6.2)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (2.6.4)
# Requirement already satisfied: sniffio in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (4.10.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<0.2,>=0.1->langchain-groq) (5.4.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<0.2,>=0.1->langchain-groq) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<0.2,>=0.1->langchain-groq) (0.1.36)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<0.2,>=0.1->langchain-groq) (23.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<0.2,>=0.1->langchain-groq) (2.28.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<0.2,>=0.1->langchain-groq) (8.1.0)
# Requirement already satisfied: idna>=2.8 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.4)
# Requirement already satisfied: certifi in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2022.9.24)
# Requirement already satisfied: httpcore==1.* in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2,>=0.1->langchain-groq) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2,>=0.1->langchain-groq) (3.10.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.16.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain-core<0.2,>=0.1->langchain-groq) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain-core<0.2,>=0.1->langchain-groq) (1.26.18)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -orch (c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dng09\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Note that to run the following code, you must have got access to Llama 2's weights and have an access token from Hugging Face. You can find instructions on the model cards on the hugging face hub: https://huggingface.co/meta-llama/Llama-2-7b-chat-hf

# %%
import uuid
import pandas as pd
import numpy as np
import qdrant_client as qc
import qdrant_client.http.models as qmodels
from torch import cuda
from qdrant_client.http.models import *
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from langchain_groq import ChatGroq
from langchain.vectorstores import Qdrant
from langchain.schema import SystemMessage, HumanMessage, AIMessage

# %%
# embedding model

embed_model_id = 'sentence-transformers/all-MiniLM-L6-v2'

device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

embed_model = HuggingFaceEmbeddings(
    model_name=embed_model_id,
    model_kwargs={'device': device},
    encode_kwargs={'device': device}
)

# %%
initialized = True

client = qc.QdrantClient(host="localhost", port=6333)
collection_name = 'Taylor_Song_DataBase'

if not initialized:
    collection = client.recreate_collection(
        collection_name=collection_name,
        vectors_config=VectorParams(size=384, distance=Distance.COSINE, on_disk=True),
        on_disk_payload=True
    )

# %%
ts_lyrics = pd.read_csv('data/cleaned_data/rag_dataset.csv')
ts_lyrics['lyrics'] = ts_lyrics['lyrics'].apply(lambda x: set([verse for verse in x.split('\n') if verse != '' and verse != ' ' and verse != '   ']))
ts_lyrics.head()
# Out:
#                        song_name         album  happy_sad  relationship  \
# 0                    cold as you  Taylor Swift        -10            -8
# 1  i'm only me when i'm with you  Taylor Swift          9            10
# 2                      invisible  Taylor Swift         -1            -4
# 3                    mary's song  Taylor Swift          5            12
# 4                       our song  Taylor Swift          5             6
#
#    feelings_of_self  glass_half_full  stages  tempo  seriousness  \
# 0                -1               -3      -3     -3           -3
# 1                 3                3       1      2            2
# 2                 0               -2       1      0            0
# 3                 0                2       1      2            3
# 4                 2                2       1      0            1
#
#    future_prospects  feelings_of_male  togetherness  \
# 0                -3                -1            -1
# 1                 2                 3             3
# 2                 0                -1            -3
# 3                 3                 3             3
# 4                 1                 3             1
#
#                                               lyrics
# 0  { Of a mess of a dreamer with the nerve to ado...
# 1  { And I don't try to hide my tears,  In a fiel...
# 2  { Whenever she walks by,  I just wanna open yo...
# 3  { And all I need is you next to me,  Take me b...
# 4  { When we're on the phone and you talk real sl...

# %%
n_chunks = sum([ len(chunk) for chunk in ts_lyrics['lyrics'] ])
print(f'The number of chunks is {n_chunks}')
# Out:
# The number of chunks is 6504

# %%
if not initialized:
    for i in range(0, len(ts_lyrics)):
        if((i+1) % 30 == 0):
            print(f'Processing song number {i+1}')
            print(f'The number of verses is {len(ts_lyrics.iloc[i]["lyrics"])}')
        song = ts_lyrics.iloc[i]
        vectors = embed_model.embed_documents(song['lyrics'])
        payload = []
        ids = []

        for verse in song['lyrics']:
            ids.append(str(uuid.uuid4()))

            payload.append({
                'page_content': verse, 
                'metadata':{
                    'song_name': f"{song['song_name']}",
                    'album': song['album'],
                    'happy_sad': song['happy_sad'].item(),
                    'relationship': song['relationship'].item(),
                    'feeling_of_self': song['feelings_of_self'].item(),
                    'glass_half_full': song['glass_half_full'].item(),
                    'stages': song['stages'].item(),
                    'tempo': song['tempo'].item(),
                    'seriousness': song['seriousness'].item(),
                    'future_prospect': song['future_prospects'].item(),
                    'feelings_of_male': song['feelings_of_male'].item(),
                    'togetherness': song['togetherness'].item(),}
            })

        client.upsert(
            collection_name=collection_name,
            points=Batch(
                ids=ids,
                vectors=vectors,
                payloads=payload
            )
        )

qdrant = Qdrant(client=client, collection_name=collection_name, embeddings=embed_model)

# %% [markdown]
# # Experiment
#
# In the following experiment, we use a short query and try to retrieve the relevant songs from the database

# %%
chat = ChatGroq(temperature=0, model_name='mixtral-8x7b-32768', api_key='groq_api_key')

# %%
# Design a preprompt that will be prepended to the users query that specify how the bot should behave

def custom_prompt(query: str):
    results = qdrant.similarity_search(query, k=3)
    source_knowledge = "\n".join([x.page_content for x in results])
    augment_prompt = f"""Detect the emotion from the query and then give the user a song from Taylor Swift that matches the emtion. The song should have a similar lyrics to the context below:

    Contexts:
    {source_knowledge}

    Query: {query}"""
    return augment_prompt

# %%
# Make a test query and perform experiment

query = 'I feel sad and lonely'

qdrant.similarity_search(query, k=5)

# prompt = HumanMessage(
#     content=custom_prompt(query)
# )

# messages = []
# messages.append(prompt)
# res = chat.invoke(messages)
# print(res.content)
[(doc.metadata['song_name'], doc.page_content) for doc in qdrant.similarity_search(query, k=5)]
# Out:
# [('the outside - 17', " I've been a lot of lonely places"),
#  ('lavender haze - 11', ' I feel (I feel)'),
#  ('22 - 38', " We're happy, free, confused, and lonely at the same time"),
#  ('enchanted - 12', ' Same old tired, lonely place'),
#  ('breathe - 16', " It's 2 AM, feelin' like I just lost a friend")]
